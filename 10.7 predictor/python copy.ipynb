# %%
from helpers import *
from models import *

# %%
model_scores = {}
model_name = []
R2 = []
MAE = []
RMSE = []

# %% [markdown]
# ### **MLP 2 LAYERED**

# %%
from helpers import *
from models import *
train_X, train_y, val_X, val_y, test_X, test_y = get_data_multistep(in_steps = 27, out_steps = 7, reshape= False)
model = MLP2_multistep('MLP2.h5', in_steps=27, out_steps=7)
model.train(train_X, train_y, val_X, val_y)
# Out:
# LSTM2_multistep model built!
# Epoch 1/100
# c:\Users\Swaroop\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 261/261 [==============================] - 1s 3ms/step - loss: 762.1222 - val_loss: 111.4899
# Epoch 2/100
# 261/261 [==============================] - 1s 3ms/step - loss: 307.9481 - val_loss: 114.9079
# Epoch 3/100
# 261/261 [==============================] - 1s 2ms/step - loss: 288.1046 - val_loss: 118.4446
# Epoch 4/100
# 261/261 [==============================] - 1s 3ms/step - loss: 276.6392 - val_loss: 89.4703
# Epoch 5/100
# 261/261 [==============================] - 1s 2ms/step - loss: 260.7992 - val_loss: 101.7447
# Epoch 6/100
# 261/261 [==============================] - 1s 2ms/step - loss: 255.5236 - val_loss: 85.5517
# Epoch 7/100
# ...

# %%
model = MLP2_multistep('MLP2.h5', in_steps=27, out_steps=7)
train_X, train_y, val_X, val_y, test_X, test_y = get_data_multistep(in_steps = 27, out_steps = 7, reshape= False)
RMSE_scores, MAE_scores, R2_scores, total_score, pred_y = model.evaluate(test_X = test_X, test_y = test_y)

model.model.predict(test_X = test_X, test_y =test_y)
print("R2 score:", R2_scores)
print("\nRMSE: ", RMSE_scores) 
print("\nMAe, scores: ", MAE_scores)

# %%
model = MLP2_multistep('MLP2.h5', in_steps=27, out_steps=7)
model.model.predict(test_X,test_y)

# %%
model.plot()

# %% [markdown]
# ### **LSTM 1 LAYERED**

# %%
from helpers import *
from models import *
train_X, train_y, val_X, val_y, test_X, test_y = get_data_multistep(in_steps = 27, out_steps = 7)
model = LSTM_multistep('LSTM.h5', in_steps=27, out_steps=7)
model.train(train_X, train_y, val_X, val_y)
# Out:
# LSTM2_multistep model built!
# Epoch 1/100
# c:\Users\Swaroop\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 261/261 [==============================] - 6s 16ms/step - loss: 5562.0781 - val_loss: 455.1813
# Epoch 2/100
# 261/261 [==============================] - 4s 14ms/step - loss: 1251.4792 - val_loss: 663.1946
# Epoch 3/100
# 261/261 [==============================] - 4s 15ms/step - loss: 1366.9701 - val_loss: 334.6819
# Epoch 4/100
# 261/261 [==============================] - 4s 14ms/step - loss: 695.5533 - val_loss: 194.2471
# Epoch 5/100
# 261/261 [==============================] - 4s 14ms/step - loss: 569.1019 - val_loss: 327.4123
# Epoch 6/100
# 261/261 [==============================] - 4s 14ms/step - loss: 625.0589 - val_loss: 149.3383
# Epoch 7/100
# ...

# %%
model = LSTM_multistep('LSTM.h5', in_steps=27, out_steps=7)
train_X, train_y, val_X, val_y, test_X, test_y = get_data_multistep(in_steps = 27, out_steps = 7)
RMSE_scores, MAE_scores, R2_scores, total_score, pred_y = model.evaluate(test_X = test_X, test_y = test_y)
print("R2 score:", R2_scores)
print("\nRMSE: ", RMSE_scores) 
print("\nMAe, scores: ", MAE_scores) 

model_name.append('LSTM single layered')
MAE.append(MAE_scores)
RMSE.append(RMSE_scores)
R2.append(R2_scores)
# Out:
# c:\Users\Swaroop\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# LSTM2_multistep model built!
# 79/79 [==============================] - 1s 5ms/step
# R2 score: [0.9915447195526873, 0.9805872443405078, 0.9643222042215412, 0.9446129565447412, 0.9233714949529161, 0.9017391576784899, 0.8822862184155317]
#
# RMSE:  [2.7847465364550477, 4.215870190504281, 5.71035822912893, 7.107679090851907, 8.35025916709958, 9.44066537580642, 10.31092866391024]
#
# MAe, scores:  [1.941851264549238, 2.548556431404624, 3.3318059471097414, 4.171357665266392, 4.89980986840553, 5.5902679030893845, 6.171590017993399]
# c:\Users\Swaroop\10.7 predictor\models.py:53: RuntimeWarning: invalid value encountered in sqrt
#   total_score = np.sqrt(total_score / (test_y.shape[0] * test_y.shape[1]))

# %%
model.plot(27,7)
# Out:
# LSTM2_multistep model built!
# 1/1 [==============================] - ETA: 0s
# c:\Users\Swaroop\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# ...
# 1/1 [==============================] - 0s 30ms/step

# %%
from helpers import *
# train_X, train_y, val_X, val_y, test_X, test_y = get_data(lag = 27)
train_X, train_y, val_X, val_y, test_X, test_y = get_data_multistep(in_steps = 27, out_steps = 7)
# train_X, train_y, val_X, val_y, test_X, test_y = get_data_CNN(lag = 27)
# train_X, train_y, val_X, val_y, test_X, test_y = get_CNN_data_multistep(in_steps = 27, out_steps =7)

# %%
RMSE_scores, MAE_scores, R2_scores, total_score, pred_y = model.evaluate(test_X = test_X, test_y = test_y)
print("R2 score:", R2_scores)
print("\nRMSE: ", RMSE_scores) 
print("\nMAe, scores: ", MAE_scores)

# %% [markdown]
# ### **LSTM 2 LAYERED**

# %%
from models import *
from helpers import  *
model = LSTM2_multistep('LSTM_2.h5', in_steps=27, out_steps=7)
model.train(train_X, train_y, val_X, val_y)
# Out:
# LSTM2_multistep model built!
# Epoch 1/100
# c:\Users\Swaroop\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 261/261 [==============================] - 11s 32ms/step - loss: 22756.2148 - val_loss: 2845.2888
# Epoch 2/100
# 261/261 [==============================] - 8s 29ms/step - loss: 2940.4419 - val_loss: 1509.5863
# Epoch 3/100
# 261/261 [==============================] - 8s 30ms/step - loss: 2842.3467 - val_loss: 852.8397
# Epoch 4/100
# 261/261 [==============================] - 8s 30ms/step - loss: 2261.2573 - val_loss: 600.5822
# Epoch 5/100
# 261/261 [==============================] - 8s 30ms/step - loss: 1972.1189 - val_loss: 706.8024
# Epoch 6/100
# 261/261 [==============================] - 8s 30ms/step - loss: 5666.0239 - val_loss: 697.6839
# Epoch 7/100
# ...

# %%
train_X, train_y, val_X, val_y, test_X, test_y = get_data_multistep(in_steps = 27, out_steps = 7)
model = LSTM2_multistep('LSTM_2.h5', in_steps=27, out_steps=7)
RMSE_scores, MAE_scores, R2_scores, total_score, pred_y = model.evaluate(test_X = test_X, test_y = test_y)
print("R2 score:", R2_scores)
print("\nRMSE: ", RMSE_scores) 
print("\nMAe, scores: ", MAE_scores) 

# model_name.append('LSTM two layered')
# MAE.append(MAE_scores)
# RMSE.append(RMSE_scores)
# R2.append(R2_scores)
# Out:
# c:\Users\Swaroop\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# LSTM2_multistep model built!
# 79/79 [==============================] - 1s 10ms/step
# R2 score: [0.9922085667988375, 0.9816000378387517, 0.9655324476069813, 0.9456335672779134, 0.9240729073209933, 0.9018350926155053, 0.8823448390154426]
#
# RMSE:  [2.673193151313665, 4.1044228902889195, 5.612670775266202, 7.041888406266998, 8.31195462510822, 9.436055651385093, 10.30836096076919]
#
# MAe, scores:  [1.7285459785170956, 2.496882858959594, 3.300109214283825, 4.159471118340207, 4.909200931739306, 5.706941790086901, 6.341646785570089]
# c:\Users\Swaroop\10.7 predictor\models.py:53: RuntimeWarning: invalid value encountered in sqrt
#   total_score = np.sqrt(total_score / (test_y.shape[0] * test_y.shape[1]))

# %%
test_y[0][0]
# Out:
# 157.2

# %%
import matplotlib.pyplot as plt
tests = [test_y[i][0] for i in range(len(test_y))]
plt.plot(tests[-5:])
preds = [pred_y[i][0] for i in range(len(pred_y))]
plt.plot(preds[-5:])

# %%
model2 = model.model

# %%
data = pd.read_csv('data.csv', parse_dates = ['Date'])
data.drop('Unnamed: 0', axis = 1, inplace = True)
data.columns = ['Dates', 'sfu']
input = data.tail(27)[['sfu']].values


input_list = input.flatten().tolist()
prediction = []

for _ in  range (100):
    seed = input_list[-27:]
    model_input = np.array(seed).reshape(1, 27, 1)
    preds = model2.predict(model_input)
    input_list.extend(preds[0][:1])
    prediction.extend(preds[0])
    
    
    
    

print(input_list)
print(prediction)
# Out:
# ...
# 1/1 [==============================] - 0s 21ms/step
# ...

# %%
len(prediction)
# Out:
# 700

# %%
import matplotlib.pyplot as plt
plt.plot(prediction[250:])
# plt.plot(input_list)

# %%
model.plot()
# Out:
# c:\Users\Swaroop\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# LSTM2_multistep model built!
# ...
# 1/1 [==============================] - 0s 24ms/step

# %% [markdown]
# ### **LSTM 3 LAYERED**

# %%
from models import *
from helpers import *
train_X, train_y, val_X, val_y, test_X, test_y = get_data_multistep(in_steps = 27, out_steps = 7)
model = LSTM3_multistep('LSTM_3.h5', in_steps=27, out_steps=7)
model.train(train_X, train_y, val_X, val_y)
# Out:
# LSTM2_multistep model built!
# Epoch 1/100
# c:\Users\Swaroop\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 261/261 [==============================] - 18s 59ms/step - loss: 15805.8730 - val_loss: 1972.0383
# Epoch 2/100
# 261/261 [==============================] - 15s 56ms/step - loss: 2771.1460 - val_loss: 2217.3989
# Epoch 3/100
# 261/261 [==============================] - 15s 56ms/step - loss: 2397.5151 - val_loss: 305.4304
# Epoch 4/100
# 261/261 [==============================] - 15s 56ms/step - loss: 816.6663 - val_loss: 263.7699
# Epoch 5/100
# 261/261 [==============================] - 15s 56ms/step - loss: 732.9108 - val_loss: 231.0546
# Epoch 6/100
# 261/261 [==============================] - 15s 58ms/step - loss: 683.6408 - val_loss: 226.1538
# Epoch 7/100
# ...

# %%
train_X, train_y, val_X, val_y, test_X, test_y = get_data_multistep(in_steps = 27, out_steps = 7)
model = LSTM3_multistep('LSTM_3.h5', in_steps=27, out_steps=7)
RMSE_scores, MAE_scores, R2_scores, total_score, pred_y = model.evaluate(test_X = test_X, test_y = test_y)
print("R2 score:", R2_scores)
print("\nRMSE: ", RMSE_scores) 
print("\nMAe, scores: ", MAE_scores) 

model_name.append('LSTM three layered')
MAE.append(MAE_scores)
RMSE.append(RMSE_scores)
R2.append(R2_scores)
# Out:
# c:\Users\Swaroop\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# LSTM2_multistep model built!
# 79/79 [==============================] - 2s 20ms/step
# R2 score: [0.9901157453962689, 0.9804279116889902, 0.9645232642256453, 0.9437101341835289, 0.9218641102534996, 0.8992781543055653, 0.879412496240927]
#
# RMSE:  [3.0108812405927954, 4.233135979467363, 5.694245311498954, 7.165373387606659, 8.431989544909717, 9.558157899368025, 10.436029038549679]
#
# MAe, scores:  [2.080980870269949, 2.630379791546071, 3.4367407164356236, 4.291422811761938, 5.025222625917843, 5.737802837929188, 6.291574375653264]
# c:\Users\Swaroop\10.7 predictor\models.py:53: RuntimeWarning: invalid value encountered in sqrt
#   total_score = np.sqrt(total_score / (test_y.shape[0] * test_y.shape[1]))

# %%
model.plot()
# Out:
# c:\Users\Swaroop\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# LSTM2_multistep model built!
# ...
# 1/1 [==============================] - 0s 28ms/step

# %% [markdown]
# ### **LSTM CNN**

# %%
from models import *
from helpers import *
train_X, train_y, val_X, val_y, test_X, test_y = get_CNN_data_multistep(in_steps = 27, out_steps =7)
cnn_lstm_model =  LSTMCNN_multistep('CNN_LSTM_MODEL.h5', in_steps = 27, out_steps =7)
cnn_lstm_model.train(train_X, train_y, val_X, val_y)
# Out:
# Epoch 1/100
# c:\Users\Swaroop\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 261/261 [==============================] - 5s 8ms/step - loss: 2520.9792 - val_loss: 161.4956
# Epoch 2/100
# 261/261 [==============================] - 1s 6ms/step - loss: 446.1159 - val_loss: 158.3809
# Epoch 3/100
# 261/261 [==============================] - 2s 6ms/step - loss: 391.2731 - val_loss: 127.7864
# Epoch 4/100
# 261/261 [==============================] - 1s 5ms/step - loss: 365.3283 - val_loss: 133.5027
# Epoch 5/100
# 261/261 [==============================] - 2s 6ms/step - loss: 332.1591 - val_loss: 111.5624
# Epoch 6/100
# 261/261 [==============================] - 2s 6ms/step - loss: 325.5420 - val_loss: 109.3415
# Epoch 7/100
# 261/261 [==============================] - 1s 6ms/step - loss: 310.9611 - val_loss: 157.2813
# ...

# %%
train_X, train_y, val_X, val_y, test_X, test_y = get_CNN_data_multistep(in_steps = 27, out_steps =7)
cnn_lstm_model =  LSTMCNN_multistep('CNN_LSTM_MODEL.h5', in_steps = 27, out_steps =7)
RMSE_scores, MAE_scores, R2_scores, total_score, pred_y = cnn_lstm_model.evaluate(test_X = test_X, test_y = test_y)
print("R2 score:", R2_scores)
print("\nRMSE: ", RMSE_scores) 
print("\nMAe, scores: ", MAE_scores) 

model_name.append('CNN LSTM')
MAE.append(MAE_scores)
RMSE.append(RMSE_scores)
R2.append(R2_scores)
# Out:
# c:\Users\Swaroop\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 79/79 [==============================] - 1s 2ms/step
# R2 score: [0.9881309454822054, 0.9755046145319543, 0.9572777212971241, 0.93639551201149, 0.9139111932874068, 0.8925160487379317, 0.873809209502693]
#
# RMSE:  [3.299360162639591, 4.735717364547578, 6.248726990795747, 7.61671315117922, 8.850710233223023, 9.87379655762377, 10.675739225053613]
#
# MAe, scores:  [2.1174231037749016, 2.864010071917782, 3.690320515037652, 4.458237473214294, 5.177133814637436, 5.882979009859038, 6.506372416405201]
# c:\Users\Swaroop\10.7 predictor\models.py:53: RuntimeWarning: invalid value encountered in sqrt
#   total_score = np.sqrt(total_score / (test_y.shape[0] * test_y.shape[1]))

# %%
cnn_lstm_model.plot_CNN()
# Out:
# c:\Users\Swaroop\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# ...
# 1/1 [==============================] - 0s 26ms/step

# %% [markdown]
# ### **MODELS COMPARISON**

# %%
scores = pd.DataFrame(model_scores)
scores
# Out:
#             model_name                                               RMSE  \
# 0  LSTM single layered  [2.7847465364550477, 4.215870190504281, 5.7103...
# 1     LSTM two layered  [2.673193151313665, 4.1044228902889195, 5.6126...
# 2   LSTM three layered  [3.0108812405927954, 4.233135979467363, 5.6942...
# 3             CNN LSTM  [3.299360162639591, 4.735717364547578, 6.24872...
#
#                                                  MAE  \
# 0  [0.8822862184155317, 0.8822862184155317, 0.882...
# 1  [0.8823448390154426, 0.8823448390154426, 0.882...
# 2  [0.879412496240927, 0.879412496240927, 0.87941...
# 3  [0.873809209502693, 0.873809209502693, 0.87380...
#
#                                             R scores
# 0  [0.9915447195526873, 0.9805872443405078, 0.964...
# 1  [0.9922085667988375, 0.9816000378387517, 0.965...
# 2  [0.9901157453962689, 0.9804279116889902, 0.964...
# 3  [0.9881309454822054, 0.9755046145319543, 0.957...

# %%
print("R2 scores \n")
for i in range(len(model_name)):
    print(model_name[i], " R2: ", R2[i])
    
print("\nRMSE scores \n")
for i in range(len(model_name)):
    print(model_name[i], "RMSE: " , RMSE[i])
    
print("\nMAE scores \n")
for i in range(len(model_name)):
    print(model_name[i], " MAE: " , MAE[i])
# Out:
# R2 scores
#
# LSTM two layered  R2:  [0.9922085667988375, 0.9816000378387517, 0.9655324476069813, 0.9456335672779134, 0.9240729073209933, 0.9018350926155053, 0.8823448390154426]
# LSTM three layered  R2:  [0.9901157453962689, 0.9804279116889902, 0.9645232642256453, 0.9437101341835289, 0.9218641102534996, 0.8992781543055653, 0.879412496240927]
# LSTM single layered  R2:  [0.9915447195526873, 0.9805872443405078, 0.9643222042215412, 0.9446129565447412, 0.9233714949529161, 0.9017391576784899, 0.8822862184155317]
# CNN LSTM  R2:  [0.9881309454822054, 0.9755046145319543, 0.9572777212971241, 0.93639551201149, 0.9139111932874068, 0.8925160487379317, 0.873809209502693]
#
# RMSE scores
#
# LSTM two layered RMSE:  [2.673193151313665, 4.1044228902889195, 5.612670775266202, 7.041888406266998, 8.31195462510822, 9.436055651385093, 10.30836096076919]
# ...

# %%
scores[['MAE']]
# Out:
#                                                  MAE
# 0  [0.8822862184155317, 0.8822862184155317, 0.882...
# 1  [0.8823448390154426, 0.8823448390154426, 0.882...
# 2  [0.879412496240927, 0.879412496240927, 0.87941...
# 3  [0.873809209502693, 0.873809209502693, 0.87380...

# %%
def plot_scores(scores, model_names, metric_name):
    plt.figure(figsize=(10, 6))
    for i, model_score in enumerate(scores):
        plt.plot(range(1, 8), model_score, label=model_names[i])
    
    plt.xlabel('Data Point')
    plt.ylabel(metric_name)
    plt.title(f'{metric_name} Comparison')
    plt.legend(loc='best')
    plt.xticks(range(1, 8))
    plt.grid(True)
    plt.show()

# %%
mae_scores = [
    [1.941851264549238, 2.548556431404624, 3.3318059471097414, 4.171357665266392, 4.89980986840553, 5.5902679030893845, 6.171590017993399],
    [1.7285459785170956, 2.496882858959594, 3.300109214283825, 4.159471118340207, 4.909200931739306, 5.706941790086901, 6.341646785570089],
    [2.080980870269949, 2.630379791546071, 3.4367407164356236, 4.291422811761938, 5.025222625917843, 5.737802837929188, 6.291574375653264],
    [2.1174231037749016, 2.864010071917782, 3.690320515037652, 4.458237473214294, 5.177133814637436, 5.882979009859038, 6.506372416405201]
]

model_names = ['LSTM Single', 'LSTM Two', 'LSTM Three', 'CNN LSTM']

metric_name = 'MAE'

plot_scores(mae_scores, model_names, metric_name)

# %%
r2_scores = [
    [0.9915447195526873, 0.9805872443405078, 0.9643222042215412, 0.9446129565447412, 0.9233714949529161, 0.9017391576784899, 0.8822862184155317],
    [0.9922085667988375, 0.9816000378387517, 0.9655324476069813, 0.9456335672779134, 0.9240729073209933, 0.9018350926155053, 0.8823448390154426],
    [0.9901157453962689, 0.9804279116889902, 0.9645232642256453, 0.9437101341835289, 0.9218641102534996, 0.8992781543055653, 0.879412496240927],
    [0.9881309454822054, 0.9755046145319543, 0.9572777212971241, 0.93639551201149, 0.9139111932874068, 0.8925160487379317, 0.873809209502693]
]

model_names = ['LSTM Single', 'LSTM Two', 'LSTM Three', 'CNN LSTM']
metric_name = 'R2'

plot_scores(r2_scores, model_names, metric_name)

# %%
rmse_scores = [
    [2.7847465364550477, 4.215870190504281, 5.71035822912893, 7.107679090851907, 8.35025916709958, 9.44066537580642, 10.31092866391024],
    [2.673193151313665, 4.1044228902889195, 5.612670775266202, 7.041888406266998, 8.31195462510822, 9.436055651385093, 10.30836096076919],
    [3.0108812405927954, 4.233135979467363, 5.694245311498954, 7.165373387606659, 8.431989544909717, 9.558157899368025, 10.436029038549679],
    [3.299360162639591, 4.735717364547578, 6.248726990795747, 7.61671315117922, 8.850710233223023, 9.87379655762377, 10.675739225053613]
]

metric_name = 'RMSE'

plot_scores(rmse_scores, model_names, metric_name)

# %%
test_x

# %%
import pandas as pd

df = pd.read_csv('data.csv')
df.drop('Unnamed: 0', inplace = True, axis = 1)
df.columns = ['Date', 'sfu']
df.Date = pd.to_datetime(df.Date)

# %%
import matplotlib.pyplot as plt
seed = df.sfu[-27:].values
predictions = []
actual = []
num_of_preds = 5
actual.extend(seed)
n = 5 
for i in range(n):
    input = actual[-27:]
    input  = np.array(input).reshape(1, 27, 1)
    preds = model.model.predict(input)
    predictions.append(preds[0][:num_of_preds])
    actual.append(preds[:num_of_preds])
    



plt.plot(seed, "input data")
plt.plot(predictions, "model predictions")
plt.legend()
# Out:
# 1/1 [==============================] - 0s 31ms/step
# C:\Users\Swaroop\AppData\Local\Temp\ipykernel_15176\2261715696.py:10: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   input  = np.array(input).reshape(1, 27, 1)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Swaroop\10.7 predictor\python.ipynb Cell 43 in 1
#       <a href='vscode-notebook-cell:/c%3A/Users/Swaroop/10.7%20predictor/python.ipynb#X61sZmlsZQ%3D%3D?line=8'>9</a> input = actual[-27:]
#      <a href='vscode-notebook-cell:/c%3A/Users/Swaroop/10.7%20predictor/python.ipynb#X61sZmlsZQ%3D%3D?line=9'>10</a> input  = np.array(input).reshape(1, 27, 1)
# ...

# %%
input = actual[-27:]

input  = np.asarray(input).astype('float32').reshape(1, 27, 1)
# input  = np.array(input).reshape(1, 27, 1)
# Out:
# C:\Users\Swaroop\AppData\Local\Temp\ipykernel_15176\3660146770.py:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   input  = np.asarray(input).astype('float32').reshape(1, 27, 1)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# c:\Users\Swaroop\10.7 predictor\python.ipynb Cell 44 in 3
#       <a href='vscode-notebook-cell:/c%3A/Users/Swaroop/10.7%20predictor/python.ipynb#X65sZmlsZQ%3D%3D?line=0'>1</a> input = actual[-27:]
# ...

# %%
model.model.predict(input)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Swaroop\10.7 predictor\python.ipynb Cell 45 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Swaroop/10.7%20predictor/python.ipynb#X63sZmlsZQ%3D%3D?line=0'>1</a> model.model.predict(input)
#
# File c:\Users\Swaroop\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# ...

# %%
preds[0][:5]
# Out:
# array([  4.2519073,   2.9765182,   2.2490315, -15.796842 ,  -6.2305536],
#       dtype=float32)

# %%
plt.plot(df.sfu[-27:].values)

# %%
model.model.predict(np.array(df.sfu[-27:].values).reshape(1, 27, 1))
# Out:
# 1/1 [==============================] - 0s 29ms/step
# array([[ -7.4942393,   8.48928  ,  -0.2880603,   0.6005822,  14.852252 ,
#         -10.256136 ,  21.086012 ]], dtype=float32)

# %%
np.array(df.sfu[-27:].values).
# Out:
# (27,)

# %%
train_X, train_y, val_X, val_y, test_X, test_y = get_data_multistep(in_steps = 27, out_steps = 7)
model = LSTM2_multistep('best_model.h5', in_steps=27, out_steps=7)
RMSE_scores, MAE_scores, R2_scores, total_score, pred_y = model.evaluate(test_X = test_X, test_y = test_y)
print("R2 score:", R2_scores)
print("\nRMSE: ", RMSE_scores) 
print("\nMAe, scores: ", MAE_scores) 

# model_name.append('LSTM two layered')
# MAE.append(MAE_scores)
# RMSE.append(RMSE_scores)
# R2.append(R2_scores)
# Out:
# c:\Users\Swaroop\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# LSTM2_multistep model built!
# 79/79 [==============================] - 1s 13ms/step
# c:\Users\Swaroop\10.7 predictor\models.py:53: RuntimeWarning: invalid value encountered in sqrt
#   total_score = np.sqrt(total_score / (test_y.shape[0] * test_y.shape[1]))
# R2 score: [0.9922085667988375, 0.9816000378387517, 0.9655324476069813, 0.9456335672779134, 0.9240729073209933, 0.9018350926155053, 0.8823448390154426]
#
# RMSE:  [2.673193151313665, 4.1044228902889195, 5.612670775266202, 7.041888406266998, 8.31195462510822, 9.436055651385093, 10.30836096076919]
#
# MAe, scores:  [1.7285459785170956, 2.496882858959594, 3.300109214283825, 4.159471118340207, 4.909200931739306, 5.706941790086901, 6.341646785570089]

# %%
model.model.predict((df.sfu[-27:].values).reshape(1, 27, 1))
# Out:
# 1/1 [==============================] - 0s 25ms/step
# array([[175.78214, 175.17554, 174.46996, 173.44037, 172.15724, 171.08752,
#         169.98451]], dtype=float32)

# %%
import random
start  = random.randint(27, 500)
seed = df.sfu[start: start + 27]
actual = []
predictions = []
actual .extend(seed)

n_pred = 7

for i in range(7):
    input = np.array(actual[-27:]).reshape(1, 27, 1)
    preds = model.model.predict(input)[0]
    predictions.extend(preds[:n_pred])
    actual.extend(preds[:n_pred])

# actual
# predictions

plt.plot(range(len(actual)), (df.sfu[start :start + len(actual)]).values, label = "actual values")
plt.plot(range(len(seed)), seed, label = "model seed")
plt.plot(range(len(seed), len(actual)), predictions, label = "predictions")

# plt.plot(df.sfu[start:start+27])
plt.legend()
# Out:
# ...
# 1/1 [==============================] - 0s 26ms/step

# %%
import random


plt.subplot(3, 2, 1)
start  = random.randint(27, 500)
seed = df.sfu[start: start + 27]
actual = []
predictions = []
actual .extend(seed)

n_pred = 7

for i in range(7):
    input = np.array(actual[-27:]).reshape(1, 27, 1)
    preds = model.model.predict(input)[0]
    predictions.extend(preds[:n_pred])
    actual.extend(preds[:n_pred])

# actual
# predictions

plt.plot(range(len(actual)), (df.sfu[start :start + len(actual)]).values, label = "actual values")
plt.plot(range(len(seed)), seed, label = "model seed")
plt.plot(range(len(seed), len(actual)), predictions, label = "predictions")

# plt.plot(df.sfu[start:start+27])
# plt.legend()


plt.subplot(3, 2, 2)
start  = random.randint(27, 500)
seed = df.sfu[start: start + 27]
actual = []
predictions = []
actual .extend(seed)

n_pred = 7

for i in range(7):
    input = np.array(actual[-27:]).reshape(1, 27, 1)
    preds = model.model.predict(input)[0]
    predictions.extend(preds[:n_pred])
    actual.extend(preds[:n_pred])

# actual
# predictions

plt.plot(range(len(actual)), (df.sfu[start :start + len(actual)]).values, label = "actual values")
plt.plot(range(len(seed)), seed, label = "model seed")
plt.plot(range(len(seed), len(actual)), predictions, label = "predictions")

# plt.plot(df.sfu[start:start+27])
# plt.legend()

plt.subplot(3, 2, 3)
start  = random.randint(27, 500)
seed = df.sfu[start: start + 27]
actual = []
predictions = []
actual .extend(seed)

n_pred = 7

for i in range(7):
    input = np.array(actual[-27:]).reshape(1, 27, 1)
    preds = model.model.predict(input)[0]
    predictions.extend(preds[:n_pred])
    actual.extend(preds[:n_pred])

# actual
# predictions

plt.plot(range(len(actual)), (df.sfu[start :start + len(actual)]).values, label = "actual values")
plt.plot(range(len(seed)), seed, label = "model seed")
plt.plot(range(len(seed), len(actual)), predictions, label = "predictions")

# plt.plot(df.sfu[start:start+27])
# plt.legend()


plt.subplot(3, 2, 4)
start  = random.randint(27, 500)
seed = df.sfu[start: start + 27]
actual = []
predictions = []
actual .extend(seed)

n_pred = 7

for i in range(7):
    input = np.array(actual[-27:]).reshape(1, 27, 1)
    preds = model.model.predict(input)[0]
    predictions.extend(preds[:n_pred])
    actual.extend(preds[:n_pred])

# actual
# predictions

plt.plot(range(len(actual)), (df.sfu[start :start + len(actual)]).values, label = "actual values")
plt.plot(range(len(seed)), seed, label = "model seed")
plt.plot(range(len(seed), len(actual)), predictions, label = "predictions")

# plt.plot(df.sfu[start:start+27])
# plt.legend()


plt.subplot(3, 2, 5)
start  = random.randint(27, 500)
seed = df.sfu[start: start + 27]
actual = []
predictions = []
actual .extend(seed)

n_pred = 7

for i in range(7):
    input = np.array(actual[-27:]).reshape(1, 27, 1)
    preds = model.model.predict(input)[0]
    predictions.extend(preds[:n_pred])
    actual.extend(preds[:n_pred])

# actual
# predictions

plt.plot(range(len(actual)), (df.sfu[start :start + len(actual)]).values, label = "actual values")
plt.plot(range(len(seed)), seed, label = "model seed")
plt.plot(range(len(seed), len(actual)), predictions, label = "predictions")

# plt.plot(df.sfu[start:start+27])
# plt.legend()


plt.subplot(3, 2, 6)
start  = random.randint(27, 500)
seed = df.sfu[start: start + 27]
actual = []
predictions = []
actual .extend(seed)

n_pred = 7

for i in range(7):
    input = np.array(actual[-27:]).reshape(1, 27, 1)
    preds = model.model.predict(input)[0]
    predictions.extend(preds[:n_pred])
    actual.extend(preds[:n_pred])

# actual
# predictions

plt.plot(range(len(actual)), (df.sfu[start :start + len(actual)]).values, label = "actual values")
plt.plot(range(len(seed)), seed, label = "model seed")
plt.plot(range(len(seed), len(actual)), predictions, label = "predictions")

# plt.plot(df.sfu[start:start+27])
# plt.legend()
# Out:
# ...
# 1/1 [==============================] - 0s 23ms/step

# %% [markdown]
# ### **CLOSED LOOP PREDICTIONS FOR SINGLE STEP**

# %%
import random


plt.subplot(3, 2, 1)
start  = random.randint(27, 500)
seed = df.sfu[start: start + 27]
actual = []
predictions = []
actual .extend(seed)

n_pred = 1

for i in range(50):
    input = np.array(actual[-27:]).reshape(1, 27, 1)
    preds = model.model.predict(input)[0]
    predictions.extend(preds[:n_pred])
    actual.extend(preds[:n_pred])

# actual
# predictions

plt.plot(range(len(actual)), (df.sfu[start :start + len(actual)]).values, label = "actual values")
plt.plot(range(len(seed)), seed, label = "model seed")
plt.plot(range(len(seed), len(actual)), predictions, label = "predictions")

# plt.plot(df.sfu[start:start+27])
# plt.legend()


plt.subplot(3, 2, 2)
start  = random.randint(27, 500)
seed = df.sfu[start: start + 27]
actual = []
predictions = []
actual .extend(seed)

n_pred = 1

for i in range(50):
    input = np.array(actual[-27:]).reshape(1, 27, 1)
    preds = model.model.predict(input)[0]
    predictions.extend(preds[:n_pred])
    actual.extend(preds[:n_pred])

# actual
# predictions

plt.plot(range(len(actual)), (df.sfu[start :start + len(actual)]).values, label = "actual values")
plt.plot(range(len(seed)), seed, label = "model seed")
plt.plot(range(len(seed), len(actual)), predictions, label = "predictions")

# plt.plot(df.sfu[start:start+27])
# plt.legend()

plt.subplot(3, 2, 3)
start  = random.randint(27, 500)
seed = df.sfu[start: start + 27]
actual = []
predictions = []
actual .extend(seed)

n_pred = 1

for i in range(50):
    input = np.array(actual[-27:]).reshape(1, 27, 1)
    preds = model.model.predict(input)[0]
    predictions.extend(preds[:n_pred])
    actual.extend(preds[:n_pred])

# actual
# predictions

plt.plot(range(len(actual)), (df.sfu[start :start + len(actual)]).values, label = "actual values")
plt.plot(range(len(seed)), seed, label = "model seed")
plt.plot(range(len(seed), len(actual)), predictions, label = "predictions")

# plt.plot(df.sfu[start:start+27])
# plt.legend()


plt.subplot(3, 2, 4)
start  = random.randint(27, 500)
seed = df.sfu[start: start + 27]
actual = []
predictions = []
actual .extend(seed)

n_pred = 1

for i in range(50):
    input = np.array(actual[-27:]).reshape(1, 27, 1)
    preds = model.model.predict(input)[0]
    predictions.extend(preds[:n_pred])
    actual.extend(preds[:n_pred])

# actual
# predictions

plt.plot(range(len(actual)), (df.sfu[start :start + len(actual)]).values, label = "actual values")
plt.plot(range(len(seed)), seed, label = "model seed")
plt.plot(range(len(seed), len(actual)), predictions, label = "predictions")

# plt.plot(df.sfu[start:start+27])
# plt.legend()


plt.subplot(3, 2, 5)
start  = random.randint(27, 500)
seed = df.sfu[start: start + 27]
actual = []
predictions = []
actual .extend(seed)

n_pred = 1

for i in range(50):
    input = np.array(actual[-27:]).reshape(1, 27, 1)
    preds = model.model.predict(input)[0]
    predictions.extend(preds[:n_pred])
    actual.extend(preds[:n_pred])

# actual
# predictions

plt.plot(range(len(actual)), (df.sfu[start :start + len(actual)]).values, label = "actual values")
plt.plot(range(len(seed)), seed, label = "model seed")
plt.plot(range(len(seed), len(actual)), predictions, label = "predictions")

# plt.plot(df.sfu[start:start+27])
# plt.legend()


plt.subplot(3, 2, 6)
start  = random.randint(27, 500)
seed = df.sfu[start: start + 27]
actual = []
predictions = []
actual .extend(seed)

n_pred = 1

for i in range(50):
    input = np.array(actual[-27:]).reshape(1, 27, 1)
    preds = model.model.predict(input)[0]
    predictions.extend(preds[:n_pred])
    actual.extend(preds[:n_pred])

# actual
# predictions

plt.plot(range(len(actual)), (df.sfu[start :start + len(actual)]).values, label = "actual values")
plt.plot(range(len(seed)), seed, label = "model seed")
plt.plot(range(len(seed), len(actual)), predictions, label = "predictions")

# plt.plot(df.sfu[start:start+27])
# plt.legend()
# Out:
# ...
# 1/1 [==============================] - 0s 24ms/step

# %%
preds[:100, 0]
# Out:
# array([150.67642 , 166.61954 , 161.57509 , 164.00491 , 170.3272  ,
#        183.02449 , 197.23128 , 192.79614 , 182.69075 , 189.0916  ,
#        186.38684 , 164.85031 , 162.05843 , 166.87283 , 157.54033 ,
#        159.79593 , 161.06082 , 168.84306 , 169.11507 , 158.44727 ,
#        146.81903 , 148.54347 , 150.46973 , 160.0866  , 158.60301 ,
#        156.2807  , 158.30103 , 157.73744 , 157.14926 , 157.71698 ,
#        157.91318 , 157.40674 , 156.46332 , 155.64243 , 155.1702  ,
#        155.19498 , 155.24321 , 155.60304 , 155.71916 , 155.47714 ,
#        154.21599 , 153.46794 , 153.21626 , 153.31474 , 153.31728 ,
#        153.10425 , 152.72115 , 152.55441 , 152.41603 , 152.2106  ,
#        151.99048 , 151.77037 , 151.55028 , 154.47832 , 156.99622 ,
#        158.89236 , 152.60027 , 147.96025 , 145.7129  , 142.52075 ,
#        146.94641 , 150.60968 , 151.54861 , 153.26468 , 154.97398 ,
#        156.39877 , 148.46042 , 142.39397 , 139.16476 , 139.65137 ,
# ...

# %%
preds = model.model.predict(test_X.reshape(-1, 27,1))
plt.plot(preds[:15, 0])
plt.plot(test_y[:15, 0])
# Out:
# 79/79 [==============================] - 1s 9ms/step

# %% [markdown]
# ### **PREDICTIONS BY SEPC**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a DataFrame
data = {
    'Datetime': ['20230613', '20230614', '20230615', '20230616', '20230617', '20230618', '20230619', '20230620', '20230621', '20230622', '20230623', '20230624', '20230625', '20230626', '20230627', '20230628', '20230629', '20230630', '20230701', '20230702', '20230703', '20230704', '20230705', '20230706', '20230707', '20230708', '20230709'],
    'Observed': [146, 144, 153, 157, 158, 164, 169, 180, 176, 173, 170, 161, 155, 158, 151, 155, 162, 159, 166, 170, 173, 167, 154, 158, 161, 161, 179],
    'Predicted': [143, 145, 144, 143, 142, 139, 140, 140, 142, 145, 149, 150, 151, 153, 155, 157, 158, 160, 162, 164, 166, 163, 159, 156, 152, 148, 146]
}

df = pd.DataFrame(data)
df['Datetime'] = pd.to_datetime(df['Datetime'])

# Plot observed and predicted values
plt.subplot(3, 2, 1)
plt.plot(df['Datetime'], df['Observed'], label='Observed')
plt.plot(df['Datetime'], df['Predicted'], label='Predicted')
plt.xlabel('Datetime')
plt.ylabel('Value')
# plt.title('Observed vs Predicted Values')
# plt.legend()
plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()



data = {
    'Datetime': ['20230308', '20230309', '20230310', '20230311', '20230312', '20230313', '20230314', '20230315', '20230316', '20230317', '20230318', '20230319', '20230320', '20230321', '20230322', '20230323', '20230324', '20230325', '20230326', '20230327', '20230328', '20230329', '20230330', '20230331', '20230401', '20230402', '20230403'],
    'Observed': [182, 179, 171, 157, 150, 143, 139, 136, 135, 134, 140, 143, 156, 152, 159, 151, 158, 160, 159, 158, 159, 148, 140, 129, 125, 127, 134],
    'Predicted': [180, 178, 174, 173, 171, 171, 170, 170, 168, 168, 164, 166, 165, 166, 165, 167, 167, 167, 168, 169, 166, 167, 167, 164, 168, 167, 169]
}

df = pd.DataFrame(data)
df['Datetime'] = pd.to_datetime(df['Datetime'])

# Plot observed and predicted values
plt.subplot(3, 2, 2)
plt.plot(df['Datetime'], df['Observed'], label='Observed')
plt.plot(df['Datetime'], df['Predicted'], label='Predicted')
plt.xlabel('Datetime')
plt.ylabel('Value')
# plt.title('Observed vs Predicted Values')
# plt.legend()
plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()



data = {
    'Datetime': ['20230112', '20230113', '20230114', '20230115', '20230116', '20230117', '20230118', '20230119', '20230120', '20230121', '20230122', '20230123', '20230124', '20230125', '20230126', '20230127', '20230128', '20230129', '20230130', '20230131', '20230201', '20230202', '20230203', '20230204', '20230205', '20230206', '20230207', '20230208', '20230209', '20230210'],
    'Observed': [212, 209, 228, 234, 228, 222, 220, 219, 218, 209, 199, 189, 180, 172, 151, 145, 138, 137, 136, 137, 134, 135, 135, 139, 144, 158, 185, 0, 0, 0],
    'Predicted': [187, 184, 178, 171, 165, 161, 155, 153, 150, 148, 145, 145, 146, 144, 145, 149, 148, 149, 151, 154, 159, 166, 169, 168, 172, 171, 169, 0, 0, 0]
}

df = pd.DataFrame(data)
df['Datetime'] = pd.to_datetime(df['Datetime'])

# Plot observed and predicted values
plt.subplot(3, 2, 3)
plt.plot(df['Datetime'], df['Observed'], label='Observed')
plt.plot(df['Datetime'], df['Predicted'], label='Predicted')
plt.xlabel('Datetime')
plt.ylabel('Value')
# plt.title('Observed vs Predicted Values')
# plt.legend()
plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()


data = {
    'Datetime': ['20230405', '20230406', '20230407', '20230408', '20230409', '20230410', '20230411', '20230412', '20230413', '20230414', '20230415', '20230416', '20230417', '20230418', '20230419', '20230420', '20230421', '20230422', '20230423', '20230424', '20230425', '20230426', '20230427', '20230428', '20230429', '20230430', '20230501'],
    'Observed': [137, 137, 136, 136, 140, 140, 143, 154, 160, 171, 176, 178, 167, 153, 147, 147, 151, 141, 135, 134, 131, 137, 141, 150, 156, 154, 148],
    'Predicted': [141, 142, 143, 145, 143, 143, 146, 148, 154, 156, 158, 158, 157, 158, 155, 155, 153, 148, 145, 143, 139, 137, 136, 137, 138, 142, 144]
}


df = pd.DataFrame(data)
df['Datetime'] = pd.to_datetime(df['Datetime'])

# Plot observed and predicted values
plt.subplot(3, 2, 4)
plt.plot(df['Datetime'], df['Observed'], label='Observed')
plt.plot(df['Datetime'], df['Predicted'], label='Predicted')
plt.xlabel('Datetime')
plt.ylabel('Value')
# plt.title('Observed vs Predicted Values')
# plt.legend()
plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()


data = {
    'Datetime': ['20230315', '20230316', '20230317', '20230318', '20230319', '20230320', '20230321', '20230322', '20230323', '20230324', '20230325', '20230326', '20230327', '20230328', '20230329', '20230330', '20230331', '20230401', '20230402', '20230403', '20230404', '20230405', '20230406', '20230407', '20230408', '20230409', '20230410'],
    'Observed': [136, 135, 134, 140, 143, 156, 152, 159, 151, 158, 160, 159, 158, 159, 148, 140, 129, 125, 127, 134, 136, 137, 137, 136, 136, 140, 140],
    'Predicted': [138, 137, 139, 138, 142, 143, 146, 148, 153, 156, 160, 164, 167, 165, 167, 168, 165, 169, 166, 166, 163, 164, 160, 158, 156, 153, 149]
}


df = pd.DataFrame(data)
df['Datetime'] = pd.to_datetime(df['Datetime'])

# Plot observed and predicted values
plt.subplot(3, 2, 5)
plt.plot(df['Datetime'], df['Observed'], label='Observed')
plt.plot(df['Datetime'], df['Predicted'], label='Predicted')
# plt.xlabel('Datetime')
# plt.ylabel('Value')
# plt.title('Observed vs Predicted Values')
# plt.legend()
plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()



data = {
    'Datetime': ['20230410', '20230411', '20230412', '20230413', '20230414', '20230415', '20230416', '20230417', '20230418', '20230419', '20230420', '20230421', '20230422', '20230423'],
    'Observed': [140, 143, 154, 160, 171, 176, 178, 167, 153, 147, 147, 151, 141, 135],
    'Predicted': [140, 145, 148, 154, 157, 159, 159, 158, 160, 157, 157, 155, 149, 146]
}

df = pd.DataFrame(data)
df['Datetime'] = pd.to_datetime(df['Datetime'])

# Plot observed and predicted values
plt.subplot(3, 2, 6)
plt.plot(df['Datetime'], df['Observed'], label='Observed')
plt.plot(df['Datetime'], df['Predicted'], label='Predicted')
# plt.xlabel('Datetime')
# plt.ylabel('Value')
# plt.title('Observed vs Predicted Values')
# plt.legend()
plt.xticks(rotation=45)
# plt.tight_layout()
# plt.show()
# Out:
# (array([19458., 19460., 19462., 19464., 19466., 19468., 19470.]),
#  [Text(19458.0, 0, '2023-04-11'),
#   Text(19460.0, 0, '2023-04-13'),
#   Text(19462.0, 0, '2023-04-15'),
#   Text(19464.0, 0, '2023-04-17'),
#   Text(19466.0, 0, '2023-04-19'),
#   Text(19468.0, 0, '2023-04-21'),
#   Text(19470.0, 0, '2023-04-23')])

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Create a DataFrame for the new data
data = {
    'Observed': [6, 7, 20, 8, 10, 24, 16, 5, 10, 13, 9, 6, 7, 11, 21, 7, 6, 9, 9, 6, 9, 12, 6, 13, 13, 36, 4, 12],
    'Predicted': [14, 28, 13, 12, 11, 10, 7, 7, 9, 12, 10, 7, 6, 9, 9, 11, 7, 7, 6, 4, 5, 7, 7, 13, 10, 5, 7, 6]
}

df = pd.DataFrame(data)
# df['Datetime'] = pd.to_datetime(df['Datetime'])

# Create subplots
# plt.figure(figsize=(12, 10))


plt.subplot(2, 1, 1)
plt.plot( df['Observed'], label='Observed')
plt.plot( df['Predicted'], label='Predicted')
plt.xlabel('Datetime')
plt.ylabel('Value')
# plt.xticks(rotation=45)
plt.title(f'Subplot {i+1}')
plt.tight_layout()




data = {
    # 'Datetime': ['20230615', '20230616', '20230617', '20230618', '20230619', '20230620', '20230621', '20230622', '20230623', '20230624', '20230625', '20230626', '20230627'],
    'Observed': [13, 5, 5, 11, 5, 7, 5, 5, 4, 5, 9, 6, 6, 5, 24, 38, 8, 10, 10, 10, 8, 8, 9, 16, 15, 11, 8],
    'Predicted': [5, 21, 14, 12, 7, 21, 17, 17, 9, 5, 9, 15, 7, 2, 7, 14, 14, 20, 13, 13, 15, 8, 3, 9, 11, 4, 5]
}

df = pd.DataFrame(data)
# df['Datetime'] = pd.to_datetime(df['Datetime'])

# Create subplots
# plt.figure(figsize=(12, 10))


plt.subplot(2, 1, 2)
plt.plot( df['Observed'], label='Observed')
plt.plot( df['Predicted'], label='Predicted')
plt.xlabel('Datetime')
plt.ylabel('Value')
# plt.xticks(rotation=45)
plt.title(f'Subplot {i+1}')
plt.tight_layout()
